# %%
import pandas as pd
import datetime

pd.set_option("display.max_columns",999)

import warnings
warnings.filterwarnings('ignore')

# %%
lease = pd.read_csv('lease_clean_data_sep24.csv', low_memory=False, 
                    keep_default_na = True).drop(columns='Unnamed: 0')

# %%
lease.head()
# Out:
#    leasedeal_id  property_id  renewal  sqft_min  sqft_max date_on_market  \
# 0     110498312       157648      NaN    3650.0    3650.0     2006-03-31
# 1      30028220        76048      NaN       NaN       NaN            NaN
# 2      30187227       559441      NaN       NaN       NaN            NaN
# 3     114096677       239837      NaN    1388.0    1388.0     2013-12-31
# 4      10587417       220914      NaN       NaN       NaN            NaN
#
#   date_off_market  days_on_market  actual_vacancy   from_date    to_date_  \
# 0      2006-12-31           275.0             1.0  2006-10-05  2014-04-29
# 1             NaN             NaN             NaN  1982-01-15  2001-04-15
# 2             NaN             NaN             NaN  1986-01-15  2000-03-14
# 3      2014-03-31            90.0             1.0  2014-02-14  2015-02-12
# 4             NaN             NaN             NaN  2001-06-30         NaN
#
#   lease_sign_date lease_expiration_date  lease_term_in_months  rate_actual  \
# 0      2006-09-05            2011-10-05                  60.0          NaN
# 1      1981-12-16            2000-04-14                 219.0          NaN
# 2      1985-12-16            2000-03-14                 170.0          NaN
# 3      2014-01-15            2015-02-13                  12.0          NaN
# 4      2001-05-01            2006-06-30                  60.0          NaN
#
#    estimated_rent  service_type_id  property_type_id  location_occupancy_id  \
# 0       39.202936              4.0                 5              111764312
# 1             NaN             11.0                 5               30028220
# 2             NaN              NaN                 5               30187227
# 3       18.914058              7.0                 5              122849533
# 4       21.278033              NaN                 5               10587417
#
#       rba  tenant_improvement_allowance_per_sqft  free_months  \
# 0  3650.0                                    NaN          NaN
# 1     NaN                                    NaN          NaN
# 2     NaN                                    NaN          NaN
# 3  1388.0                                    NaN          NaN
# 4  7200.0                                    NaN          NaN
#
#    construction_year  building_rating_id research_market_name   cbsaid  \
# 0             1928.0                   3        New York City  35614.0
# 1             1977.0                   3          Kansas City  28140.0
# 2             1985.0                   2          Kansas City  28140.0
# 3             1972.0                   2              Houston  26420.0
# 4             1906.0                   2               Boston  14460.0
#
#                          cbsa_cities cbsa_states submarket_name      zip  \
# 0  New York-Jersey City-White Plains       NY-NJ    Murray Hill  10016.0
# 1                        Kansas City       MO-KS   Ward Parkway  64114.0
# 2                        Kansas City       MO-KS  I-29 Corridor  64152.0
# 3   Houston-The Woodlands-Sugar Land          TX       Riverway  77024.0
# 4            Boston-Cambridge-Newton       MA-NH  Route 3 South   2382.0
#
#   currently_occupied_fl  year_on_market  year_off_market delete_rec  \
# 0                     N          2006.0           2006.0          N
# 1                     N             NaN              NaN          N
# 2                     N             NaN              NaN          N
# 3                     N          2013.0           2014.0          N
# 4                     Y             NaN              NaN          N
#
#   new_from_date new_to_date  year_from  year_to  years_occupied  \
# 0    2006-10-05  2014-04-29       2006     2014               8
# 1    1982-01-15  2001-04-15       1982     2001              19
# 2    1986-01-15  2000-03-14       1986     2000              14
# 3    2014-02-14  2015-02-12       2014     2015               1
# 4    2001-06-30  2021-12-31       2001     2021              20
#
#    actual_estimated_rent
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
print(lease.shape)
lease.columns
# Out:
# (1067026, 40)
# Index(['leasedeal_id', 'property_id', 'renewal', 'sqft_min', 'sqft_max',
#        'date_on_market', 'date_off_market', 'days_on_market', 'actual_vacancy',
#        'from_date', 'to_date_', 'lease_sign_date', 'lease_expiration_date',
#        'lease_term_in_months', 'rate_actual', 'estimated_rent',
#        'service_type_id', 'property_type_id', 'location_occupancy_id', 'rba',
#        'tenant_improvement_allowance_per_sqft', 'free_months',
#        'construction_year', 'building_rating_id', 'research_market_name',
#        'cbsaid', 'cbsa_cities', 'cbsa_states', 'submarket_name', 'zip',
#        'currently_occupied_fl', 'year_on_market', 'year_off_market',
#        'delete_rec', 'new_from_date', 'new_to_date', 'year_from', 'year_to',
#        'years_occupied', 'actual_estimated_rent'],
#       dtype='object')

# %%
cnt_service= pd.DataFrame(lease.groupby(['cbsaid', 'submarket_name', 'property_type_id']).agg({'property_id': 'count'})).\
                          reset_index()
cnt_service = cnt_service.pivot(index=['cbsaid', 'submarket_name'], columns='property_type_id', values='property_id').reset_index()
cnt_service = cnt_service.add_prefix('property_type_id_').\
 rename(columns={'property_type_id_submarket_name':'submarket_name', 
                 'property_type_id_cbsaid':'cbsaid'})
cnt_service
# Out:
# property_type_id   cbsaid        submarket_name  property_type_id_5
# 0                 10100.0              Aberdeen                  13
# 1                 10140.0              Aberdeen                  19
# 2                 10180.0               Abilene                  52
# 3                 10180.0  Chimney Rock Area MF                   2
# 4                 10180.0   Downtown Abilene MF                  41
# ...                   ...                   ...                 ...
# 3701              49700.0           Yuba County                   7
# 3702              49740.0      Downtown Yuma MF                  24
# 3703              49740.0                  Yuma                  18
# 3704              49780.0            Zanesville                  47
# 3705              49820.0                Zapata                   4
#
# [3706 rows x 3 columns]

# %%
cnt_building_rate= pd.DataFrame(lease.groupby(['cbsaid', 'submarket_name', 'building_rating_id']).\
                                agg({'property_id': 'count'})).\
                          reset_index()

cnt_building_rate = cnt_building_rate.pivot(index=['cbsaid', 'submarket_name'],
                                    columns='building_rating_id', values='property_id').reset_index()
cnt_building_rate = cnt_building_rate.add_prefix('building_rating_').\
        rename(columns={'building_rating_submarket_name':'submarket_name',
                       'building_rating_cbsaid':'cbsaid'})
cnt_building_rate
# Out:
# building_rating_id   cbsaid        submarket_name  building_rating_1  \
# 0                   10100.0              Aberdeen                1.0
# 1                   10140.0              Aberdeen                NaN
# 2                   10180.0               Abilene                NaN
# 3                   10180.0  Chimney Rock Area MF                NaN
# 4                   10180.0   Downtown Abilene MF                NaN
# ...                     ...                   ...                ...
# 3701                49700.0           Yuba County                4.0
# 3702                49740.0      Downtown Yuma MF                1.0
# 3703                49740.0                  Yuma                NaN
# 3704                49780.0            Zanesville                4.0
# 3705                49820.0                Zapata                NaN
#
# building_rating_id  building_rating_2  building_rating_3  building_rating_4  \
# 0                                 9.0                3.0                NaN
# 1                                10.0                9.0                NaN
# 2                                40.0               12.0                NaN
# 3                                 2.0                NaN                NaN
# 4                                14.0                2.0               25.0
# ...                               ...                ...                ...
# 3701                              3.0                NaN                NaN
# 3702                             17.0                6.0                NaN
# 3703                             12.0                6.0                NaN
# 3704                             33.0               10.0                NaN
# 3705                              4.0                NaN                NaN
#
# building_rating_id  building_rating_5
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 3701                              NaN
# 3702                              NaN
# 3703                              NaN
# 3704                              NaN
# 3705                              NaN
#
# [3706 rows x 7 columns]

# %%
lease['const_2000_fl'] = lease.construction_year.apply(lambda x: 'Y' if x > 2000 else 'N')
cnt_const_year= pd.DataFrame(lease.groupby(['cbsaid', 'submarket_name', 'const_2000_fl']).\
                             agg({'property_id': 'count'})).\
                          reset_index()
cnt_const_year = cnt_const_year.pivot(index=['cbsaid', 'submarket_name'], columns='const_2000_fl', 
                                      values='property_id').reset_index()

cnt_const_year = cnt_const_year.add_prefix('construction_after_2000_').\
        rename(columns={'construction_after_2000_submarket_name':'submarket_name',
                       'construction_after_2000_cbsaid':'cbsaid'})
cnt_const_year
# Out:
# const_2000_fl   cbsaid        submarket_name  construction_after_2000_N  \
# 0              10100.0              Aberdeen                       11.0
# 1              10140.0              Aberdeen                       17.0
# 2              10180.0               Abilene                       45.0
# 3              10180.0  Chimney Rock Area MF                        2.0
# 4              10180.0   Downtown Abilene MF                       41.0
# ...                ...                   ...                        ...
# 3701           49700.0           Yuba County                        7.0
# 3702           49740.0      Downtown Yuma MF                       13.0
# 3703           49740.0                  Yuma                       15.0
# 3704           49780.0            Zanesville                       41.0
# 3705           49820.0                Zapata                        4.0
#
# const_2000_fl  construction_after_2000_Y
# 0                                    2.0
# 1                                    2.0
# 2                                    7.0
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 3701                                 NaN
# 3702                                11.0
# 3703                                 3.0
# 3704                                 6.0
# 3705                                 NaN
#
# [3706 rows x 4 columns]

# %%
cnt_props = pd.DataFrame(lease.groupby(['cbsaid', 'submarket_name']).agg({'property_id': 'count'})).\
                          reset_index().rename(columns = {'property_id':'count_properties'})

cnt_props
# Out:
#        cbsaid        submarket_name  count_properties
# 0     10100.0              Aberdeen                13
# 1     10140.0              Aberdeen                19
# 2     10180.0               Abilene                52
# 3     10180.0  Chimney Rock Area MF                 2
# 4     10180.0   Downtown Abilene MF                41
# ...       ...                   ...               ...
# 3701  49700.0           Yuba County                 7
# 3702  49740.0      Downtown Yuma MF                24
# 3703  49740.0                  Yuma                18
# 3704  49780.0            Zanesville                47
# 3705  49820.0                Zapata                 4
#
# [3706 rows x 3 columns]

# %%
lease['renewal_fl'] = lease['renewal'].apply(lambda x:   'Y' if x is not None else 'N')
cnt_renewal= pd.DataFrame(lease.groupby(['cbsaid', 'submarket_name', 'renewal_fl']).agg({'property_id': 'count'})).\
                          reset_index()
cnt_renewal = cnt_renewal.pivot(index=['cbsaid','submarket_name'], columns='renewal_fl', values='property_id').reset_index()
cnt_renewal = cnt_renewal.add_prefix('renewal_').rename(columns={'renewal_submarket_name':'submarket_name',
                                                                'renewal_cbsaid':'cbsaid'})

cnt_renewal
# Out:
# renewal_fl   cbsaid        submarket_name  renewal_Y
# 0           10100.0              Aberdeen         13
# 1           10140.0              Aberdeen         19
# 2           10180.0               Abilene         52
# 3           10180.0  Chimney Rock Area MF          2
# 4           10180.0   Downtown Abilene MF         41
# ...             ...                   ...        ...
# 3701        49700.0           Yuba County          7
# 3702        49740.0      Downtown Yuma MF         24
# 3703        49740.0                  Yuma         18
# 3704        49780.0            Zanesville         47
# 3705        49820.0                Zapata          4
#
# [3706 rows x 3 columns]

# %%
#remove outliers in vacant properties. Use for later
import plotly.express as px
vac= lease[lease['days_on_market'].notnull()]
vac.shape
# Out:
# (589103, 42)

# %%
vac['days_vacant'] = (pd.to_datetime(vac['date_off_market']) - pd.to_datetime(vac['date_on_market'])).dt.days
cnt_vacant_service= pd.DataFrame(vac.groupby(['cbsaid', 'submarket_name',  'property_type_id']).\
                                 agg({'days_vacant': 'mean'})).\
                          reset_index()
cnt_vacant_service = cnt_vacant_service.pivot(index=['cbsaid','submarket_name'], 
        columns='property_type_id', values='days_vacant').reset_index()
cnt_vacant_service = cnt_vacant_service.add_prefix('vacant_days_propertytype_').\
    rename(columns={'vacant_days_propertytype_submarket_name':'submarket_name',
                   'vacant_days_propertytype_cbsaid':'cbsaid'})

cnt_vacant_service
# Out:
# property_type_id   cbsaid        submarket_name  vacant_days_propertytype_5
# 0                 10100.0              Aberdeen                  365.714286
# 1                 10140.0              Aberdeen                  662.000000
# 2                 10180.0               Abilene                  373.411765
# 3                 10180.0  Chimney Rock Area MF                  229.000000
# 4                 10180.0   Downtown Abilene MF                  524.483871
# ...                   ...                   ...                         ...
# 3542              49700.0             Yuba City                   92.000000
# 3543              49700.0           Yuba County                  300.285714
# 3544              49740.0      Downtown Yuma MF                  298.086957
# 3545              49740.0                  Yuma                  281.166667
# 3546              49780.0            Zanesville                  749.323529
#
# [3547 rows x 3 columns]

# %%
cnt_vacant_building_rating= pd.DataFrame(vac.groupby(['cbsaid', 'submarket_name', 'building_rating_id']).\
                                         agg({'days_vacant': 'mean'})).\
                          reset_index()
cnt_vacant_building_rating = cnt_vacant_building_rating.pivot(index=['cbsaid','submarket_name'], 
                                                              columns='building_rating_id', 
                                                              values='days_vacant').reset_index()
cnt_vacant_building_rating = cnt_vacant_building_rating.add_prefix('vacant_days_buildingrating_').\
        rename(columns={'vacant_days_buildingrating_submarket_name':'submarket_name',
                       'vacant_days_buildingrating_cbsaid':'cbsaid'})

cnt_vacant_building_rating
# Out:
# building_rating_id   cbsaid        submarket_name  \
# 0                   10100.0              Aberdeen
# 1                   10140.0              Aberdeen
# 2                   10180.0               Abilene
# 3                   10180.0  Chimney Rock Area MF
# 4                   10180.0   Downtown Abilene MF
# ...                     ...                   ...
# 3542                49700.0             Yuba City
# 3543                49700.0           Yuba County
# 3544                49740.0      Downtown Yuma MF
# 3545                49740.0                  Yuma
# 3546                49780.0            Zanesville
#
# building_rating_id  vacant_days_buildingrating_1  \
# 0                                         914.00
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 3542                                         NaN
# 3543                                      365.75
# 3544                                      549.00
# 3545                                         NaN
# 3546                                      730.25
#
# building_rating_id  vacant_days_buildingrating_2  \
# 0                                     297.000000
# 1                                     502.750000
# 2                                     416.000000
# 3                                     229.000000
# 4                                     502.250000
# ...                                          ...
# 3542                                   92.000000
# 3543                                  213.000000
# 3544                                  311.823529
# 3545                                  353.000000
# 3546                                  771.148148
#
# building_rating_id  vacant_days_buildingrating_3  \
# 0                                     229.000000
# 1                                     821.250000
# 2                                     209.142857
# 3                                            NaN
# 4                                     275.000000
# ...                                          ...
# 3542                                         NaN
# 3543                                         NaN
# 3544                                  201.200000
# 3545                                  137.500000
# 3546                                  578.333333
#
# building_rating_id  vacant_days_buildingrating_4  vacant_days_buildingrating_5
# 0                                            NaN                           NaN
# 1                                            NaN                           NaN
# 2                                            NaN                           NaN
# 3                                            NaN                           NaN
# 4                                     553.166667                           NaN
# ...                                          ...                           ...
# 3542                                         NaN                           NaN
# 3543                                         NaN                           NaN
# 3544                                         NaN                           NaN
# 3545                                         NaN                           NaN
# 3546                                         NaN                           NaN
#
# [3547 rows x 7 columns]

# %%
occupied = lease.copy()
occupied['new_to_date'] = occupied['new_to_date'].fillna('2021-09-01')
occupied[occupied['new_to_date'].isnull()]
occupied
# Out:
#          leasedeal_id  property_id  renewal  sqft_min  sqft_max  \
# 0           110498312       157648      NaN    3650.0    3650.0
# 1            30028220        76048      NaN       NaN       NaN
# 2            30187227       559441      NaN       NaN       NaN
# 3           114096677       239837      NaN    1388.0    1388.0
# 4            10587417       220914      NaN       NaN       NaN
# ...               ...          ...      ...       ...       ...
# 1067021     111384471       300227      NaN    1750.0    1750.0
# 1067022      30011451        61383      NaN       NaN       NaN
# 1067023     113201416      4157322      NaN    2500.0    2500.0
# 1067024      10541376       303542      NaN       NaN       NaN
# 1067025     113371055      5573489      NaN     986.0     986.0
#
#         date_on_market date_off_market  days_on_market  actual_vacancy  \
# 0           2006-03-31      2006-12-31           275.0             1.0
# 1                  NaN             NaN             NaN             NaN
# 2                  NaN             NaN             NaN             NaN
# 3           2013-12-31      2014-03-31            90.0             1.0
# 4                  NaN             NaN             NaN             NaN
# ...                ...             ...             ...             ...
# 1067021     2008-06-30      2009-03-31           274.0             1.0
# 1067022            NaN             NaN             NaN             NaN
# 1067023     2011-06-30      2012-06-30           366.0             1.0
# 1067024            NaN             NaN             NaN             NaN
# 1067025     2009-12-31      2012-09-30          1004.0             1.0
#
#           from_date    to_date_ lease_sign_date lease_expiration_date  \
# 0        2006-10-05  2014-04-29      2006-09-05            2011-10-05
# 1        1982-01-15  2001-04-15      1981-12-16            2000-04-14
# 2        1986-01-15  2000-03-14      1985-12-16            2000-03-14
# 3        2014-02-14  2015-02-12      2014-01-15            2015-02-13
# 4        2001-06-30         NaN      2001-05-01            2006-06-30
# ...             ...         ...             ...                   ...
# 1067021  2009-01-01  2016-11-30      2008-11-18            2014-01-01
# 1067022  1988-06-15  1988-06-15      1988-05-16            1997-12-14
# 1067023  2012-05-15         NaN      2012-04-15            2015-05-14
# 1067024  2002-02-01  2002-03-04      2002-01-01            2003-01-31
# 1067025  2012-09-19  2016-01-24      2012-09-19            2015-09-18
#
#          lease_term_in_months  rate_actual  estimated_rent  service_type_id  \
# 0                        60.0          NaN       39.202936              4.0
# 1                       219.0          NaN             NaN             11.0
# 2                       170.0          NaN             NaN              NaN
# 3                        12.0          NaN       18.914058              7.0
# 4                        60.0          NaN       21.278033              NaN
# ...                       ...          ...             ...              ...
# 1067021                  60.0          NaN       21.513206              4.0
# 1067022                 114.0          NaN             NaN             11.0
# 1067023                  36.0         15.0       15.071205              6.0
# 1067024                  12.0          NaN       32.398496             13.0
# 1067025                  36.0         15.5       15.653862              7.0
#
#          property_type_id  location_occupancy_id     rba  \
# 0                       5              111764312  3650.0
# 1                       5               30028220     NaN
# 2                       5               30187227     NaN
# 3                       5              122849533  1388.0
# 4                       5               10587417  7200.0
# ...                   ...                    ...     ...
# 1067021                 5              114180680  1750.0
# 1067022                 5               30011451     NaN
# 1067023                 5              120804094  2500.0
# 1067024                 5               10541376  2395.0
# 1067025                 5              121253938   986.0
#
#          tenant_improvement_allowance_per_sqft  free_months  \
# 0                                          NaN          NaN
# 1                                          NaN          NaN
# 2                                          NaN          NaN
# 3                                          NaN          NaN
# 4                                          NaN          NaN
# ...                                        ...          ...
# 1067021                                    NaN          NaN
# 1067022                                    NaN          NaN
# 1067023                                    NaN          NaN
# 1067024                                    NaN          NaN
# 1067025                                    NaN          NaN
#
#          construction_year  building_rating_id research_market_name   cbsaid  \
# 0                   1928.0                   3        New York City  35614.0
# 1                   1977.0                   3          Kansas City  28140.0
# 2                   1985.0                   2          Kansas City  28140.0
# 3                   1972.0                   2              Houston  26420.0
# 4                   1906.0                   2               Boston  14460.0
# ...                    ...                 ...                  ...      ...
# 1067021             1965.0                   3         Philadelphia  37980.0
# 1067022             1902.0                   4           Pittsburgh  38300.0
# 1067023             1923.0                   2              Chicago  16980.0
# 1067024             1964.0                   2   South Bay/San Jose  41940.0
# 1067025             1930.0                   3     Boise City/Nampa  14260.0
#
#                                cbsa_cities   cbsa_states  \
# 0        New York-Jersey City-White Plains         NY-NJ
# 1                              Kansas City         MO-KS
# 2                              Kansas City         MO-KS
# 3         Houston-The Woodlands-Sugar Land            TX
# 4                  Boston-Cambridge-Newton         MA-NH
# ...                                    ...           ...
# 1067021     Philadelphia-Camden-Wilmington   PA-NJ-DE-MD
# 1067022                         Pittsburgh            PA
# 1067023           Chicago-Naperville-Elgin      IL-IN-WI
# 1067024     San Jose-Sunnyvale-Santa Clara            CA
# 1067025                         Boise City            ID
#
#                        submarket_name      zip currently_occupied_fl  \
# 0                         Murray Hill  10016.0                     N
# 1                        Ward Parkway  64114.0                     N
# 2                       I-29 Corridor  64152.0                     N
# 3                            Riverway  77024.0                     N
# 4                       Route 3 South   2382.0                     Y
# ...                               ...      ...                   ...
# 1067021            Market Street West  19102.0                     N
# 1067022                           CBD  15219.0                     N
# 1067023  Fulton Market/Near West Side  60607.0                     Y
# 1067024            Los Gatos/Saratoga  95030.0                     N
# 1067025                Downtown Boise  83702.0                     N
#
#          year_on_market  year_off_market delete_rec new_from_date new_to_date  \
# 0                2006.0           2006.0          N    2006-10-05  2014-04-29
# 1                   NaN              NaN          N    1982-01-15  2001-04-15
# 2                   NaN              NaN          N    1986-01-15  2000-03-14
# 3                2013.0           2014.0          N    2014-02-14  2015-02-12
# 4                   NaN              NaN          N    2001-06-30  2021-12-31
# ...                 ...              ...        ...           ...         ...
# 1067021          2008.0           2009.0          N    2009-01-01  2016-11-30
# 1067022             NaN              NaN          N    1988-06-15  1988-06-15
# 1067023          2011.0           2012.0          N    2012-05-15  2021-12-31
# 1067024             NaN              NaN          N    2002-02-01  2002-03-04
# 1067025          2009.0           2012.0          N    2012-09-19  2016-01-24
#
#          year_from  year_to  years_occupied  actual_estimated_rent  \
# 0             2006     2014               8                    NaN
# 1             1982     2001              19                    NaN
# 2             1986     2000              14                    NaN
# 3             2014     2015               1                    NaN
# 4             2001     2021              20                    NaN
# ...            ...      ...             ...                    ...
# 1067021       2009     2016               7                    NaN
# 1067022       1988     1988               0                    NaN
# 1067023       2012     2021               9               0.995275
# 1067024       2002     2002               0                    NaN
# 1067025       2012     2016               4               0.990171
#
#         const_2000_fl renewal_fl
# 0                   N          Y
# 1                   N          Y
# 2                   N          Y
# 3                   N          Y
# 4                   N          Y
# ...               ...        ...
# 1067021             N          Y
# 1067022             N          Y
# 1067023             N          Y
# 1067024             N          Y
# 1067025             N          Y
#
# [1067026 rows x 42 columns]

# %%
occupied['days_occupied'] = (pd.to_datetime(occupied['new_to_date']) - pd.to_datetime(occupied['new_from_date'])).dt.days

cnt_occ_service= pd.DataFrame(occupied.groupby(['cbsaid','submarket_name', 'property_type_id']).\
                              agg({'days_occupied': 'mean'})).\
                          reset_index()
cnt_occ_service = cnt_occ_service.pivot(index=['cbsaid','submarket_name'], columns='property_type_id', 
                                        values='days_occupied').reset_index()
cnt_occ_service = cnt_occ_service.add_prefix('occupied_days_propertytype_').\
    rename(columns={'occupied_days_propertytype_submarket_name':'submarket_name',
                   'occupied_days_propertytype_cbsaid':'cbsaid'})

cnt_occ_service
# Out:
# property_type_id   cbsaid        submarket_name  occupied_days_propertytype_5
# 0                 10100.0              Aberdeen                   3297.230769
# 1                 10140.0              Aberdeen                   2561.052632
# 2                 10180.0               Abilene                   3641.288462
# 3                 10180.0  Chimney Rock Area MF                   4848.500000
# 4                 10180.0   Downtown Abilene MF                   2287.195122
# ...                   ...                   ...                           ...
# 3701              49700.0           Yuba County                   3086.714286
# 3702              49740.0      Downtown Yuma MF                   2388.666667
# 3703              49740.0                  Yuma                   2974.166667
# 3704              49780.0            Zanesville                   2580.510638
# 3705              49820.0                Zapata                   1376.250000
#
# [3706 rows x 3 columns]

# %%
cnt_occ_buildingrating = pd.DataFrame(occupied.groupby(['cbsaid','submarket_name', 'building_rating_id']).\
                                      agg({'days_occupied': 'mean'})).\
                          reset_index()
cnt_occ_buildingrating = cnt_occ_buildingrating.pivot(index=['cbsaid','submarket_name'], 
                                            columns='building_rating_id', values='days_occupied').reset_index()
cnt_occ_buildingrating = cnt_occ_buildingrating.add_prefix('occupied_days_buildingrating_').\
        rename(columns={'occupied_days_buildingrating_submarket_name':'submarket_name',
                       'occupied_days_buildingrating_cbsaid':'cbsaid'})

cnt_occ_buildingrating
# Out:
# building_rating_id   cbsaid        submarket_name  \
# 0                   10100.0              Aberdeen
# 1                   10140.0              Aberdeen
# 2                   10180.0               Abilene
# 3                   10180.0  Chimney Rock Area MF
# 4                   10180.0   Downtown Abilene MF
# ...                     ...                   ...
# 3701                49700.0           Yuba County
# 3702                49740.0      Downtown Yuma MF
# 3703                49740.0                  Yuma
# 3704                49780.0            Zanesville
# 3705                49820.0                Zapata
#
# building_rating_id  occupied_days_buildingrating_1  \
# 0                                          1238.00
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 3701                                       3598.00
# 3702                                       3408.00
# 3703                                           NaN
# 3704                                       3126.75
# 3705                                           NaN
#
# building_rating_id  occupied_days_buildingrating_2  \
# 0                                      3278.666667
# 1                                      2547.300000
# 2                                      4041.750000
# 3                                      4848.500000
# 4                                      2870.714286
# ...                                            ...
# 3701                                   2405.000000
# 3702                                   2762.470588
# 3703                                   3257.250000
# 3704                                   2488.121212
# 3705                                   1376.250000
#
# building_rating_id  occupied_days_buildingrating_3  \
# 0                                      4039.333333
# 1                                      2576.333333
# 2                                      2306.416667
# 3                                              NaN
# 4                                      1263.500000
# ...                                            ...
# 3701                                           NaN
# 3702                                   1159.666667
# 3703                                   2408.000000
# 3704                                   2666.900000
# 3705                                           NaN
#
# building_rating_id  occupied_days_buildingrating_4  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                          2042.32
# ...                                            ...
# 3701                                           NaN
# 3702                                           NaN
# 3703                                           NaN
# 3704                                           NaN
# 3705                                           NaN
#
# building_rating_id  occupied_days_buildingrating_5
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 3701                                           NaN
# 3702                                           NaN
# 3703                                           NaN
# 3704                                           NaN
# 3705                                           NaN
#
# [3706 rows x 7 columns]

# %%
cnt_currently_occupied = pd.DataFrame(lease.groupby(['cbsaid','submarket_name', 'currently_occupied_fl']).\
                                      agg({'property_id': 'count'}).\
                          reset_index())
cnt_currently_occupied = cnt_currently_occupied.pivot(index=['cbsaid','submarket_name'], 
                                                      columns='currently_occupied_fl', values='property_id').reset_index()
cnt_currently_occupied = cnt_currently_occupied.add_prefix('currently_occupied_fl_').\
        rename(columns={'currently_occupied_fl_submarket_name':'submarket_name',
                       'currently_occupied_fl_cbsaid':'cbsaid'})

cnt_currently_occupied
# Out:
# currently_occupied_fl   cbsaid        submarket_name  currently_occupied_fl_N  \
# 0                      10100.0              Aberdeen                      5.0
# 1                      10140.0              Aberdeen                      9.0
# 2                      10180.0               Abilene                     13.0
# 3                      10180.0  Chimney Rock Area MF                      NaN
# 4                      10180.0   Downtown Abilene MF                     10.0
# ...                        ...                   ...                      ...
# 3701                   49700.0           Yuba County                      1.0
# 3702                   49740.0      Downtown Yuma MF                      8.0
# 3703                   49740.0                  Yuma                      2.0
# 3704                   49780.0            Zanesville                     10.0
# 3705                   49820.0                Zapata                      3.0
#
# currently_occupied_fl  currently_occupied_fl_Y
# 0                                          8.0
# 1                                         10.0
# 2                                         39.0
# 3                                          2.0
# 4                                         31.0
# ...                                        ...
# 3701                                       6.0
# 3702                                      16.0
# 3703                                      16.0
# 3704                                      37.0
# 3705                                       1.0
#
# [3706 rows x 4 columns]

# %%
cnt_avg_rent_building_rating = pd.DataFrame(lease.groupby(['cbsaid','submarket_name', 'building_rating_id']).\
                                      agg({'estimated_rent': 'mean'}).\
                          reset_index())
cnt_avg_rent_building_rating = cnt_avg_rent_building_rating.pivot(index=['cbsaid','submarket_name'], 
                                    columns='building_rating_id', values='estimated_rent').reset_index()
cnt_avg_rent_building_rating = cnt_avg_rent_building_rating.add_prefix('avg_rent_buildingrating_').\
        rename(columns={'avg_rent_buildingrating_submarket_name':'submarket_name',
                       'avg_rent_buildingrating_cbsaid':'cbsaid'})

cnt_avg_rent_building_rating
# Out:
# building_rating_id   cbsaid        submarket_name  avg_rent_buildingrating_1  \
# 0                   10100.0              Aberdeen                  12.425771
# 1                   10140.0              Aberdeen                        NaN
# 2                   10180.0               Abilene                        NaN
# 3                   10180.0  Chimney Rock Area MF                        NaN
# 4                   10180.0   Downtown Abilene MF                        NaN
# ...                     ...                   ...                        ...
# 3701                49700.0           Yuba County                  11.876562
# 3702                49740.0      Downtown Yuma MF                  17.465653
# 3703                49740.0                  Yuma                        NaN
# 3704                49780.0            Zanesville                  11.380579
# 3705                49820.0                Zapata                        NaN
#
# building_rating_id  avg_rent_buildingrating_2  avg_rent_buildingrating_3  \
# 0                                   12.624866                  12.970470
# 1                                   16.366925                  17.534617
# 2                                   11.751387                  14.080592
# 3                                   12.777495                        NaN
# 4                                   10.670866                  12.764639
# ...                                       ...                        ...
# 3701                                12.381419                        NaN
# 3702                                16.742804                  27.180419
# 3703                                16.435734                  20.225657
# 3704                                13.444017                  15.771025
# 3705                                11.940065                        NaN
#
# building_rating_id  avg_rent_buildingrating_4  avg_rent_buildingrating_5
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                         NaN                        NaN
# 4                                   13.225918                        NaN
# ...                                       ...                        ...
# 3701                                      NaN                        NaN
# 3702                                      NaN                        NaN
# 3703                                      NaN                        NaN
# 3704                                      NaN                        NaN
# 3705                                      NaN                        NaN
#
# [3706 rows x 7 columns]

# %%
cnt_avg_rent = pd.DataFrame(lease.groupby(['cbsaid','submarket_name']).\
                                      agg({'estimated_rent': 'mean'}).\
                          reset_index())
cnt_avg_rent = cnt_avg_rent.rename(columns = {'estimated_rent': 'avg_estimated_rent'}) 
cnt_avg_rent
# Out:
#        cbsaid        submarket_name  avg_estimated_rent
# 0     10100.0              Aberdeen           12.689305
# 1     10140.0              Aberdeen           16.920042
# 2     10180.0               Abilene           12.285163
# 3     10180.0  Chimney Rock Area MF           12.777495
# 4     10180.0   Downtown Abilene MF           12.260305
# ...       ...                   ...                 ...
# 3701  49700.0           Yuba County           12.092929
# 3702  49740.0      Downtown Yuma MF           19.382326
# 3703  49740.0                  Yuma           17.518569
# 3704  49780.0            Zanesville           13.770459
# 3705  49820.0                Zapata           11.940065
#
# [3706 rows x 3 columns]

# %%
final = pd.merge(cnt_props, cnt_const_year, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_service, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_building_rate, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_renewal, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_vacant_service, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_vacant_building_rating, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_occ_service, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_occ_buildingrating, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_currently_occupied, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_avg_rent_building_rating, on = ['cbsaid','submarket_name'], how='left')
final = pd.merge(final, cnt_avg_rent, on = ['cbsaid','submarket_name'], how='left')

final
# Out:
#        cbsaid        submarket_name  count_properties  \
# 0     10100.0              Aberdeen                13
# 1     10140.0              Aberdeen                19
# 2     10180.0               Abilene                52
# 3     10180.0  Chimney Rock Area MF                 2
# 4     10180.0   Downtown Abilene MF                41
# ...       ...                   ...               ...
# 3701  49700.0           Yuba County                 7
# 3702  49740.0      Downtown Yuma MF                24
# 3703  49740.0                  Yuma                18
# 3704  49780.0            Zanesville                47
# 3705  49820.0                Zapata                 4
#
#       construction_after_2000_N  construction_after_2000_Y  \
# 0                          11.0                        2.0
# 1                          17.0                        2.0
# 2                          45.0                        7.0
# 3                           2.0                        NaN
# 4                          41.0                        NaN
# ...                         ...                        ...
# 3701                        7.0                        NaN
# 3702                       13.0                       11.0
# 3703                       15.0                        3.0
# 3704                       41.0                        6.0
# 3705                        4.0                        NaN
#
#       property_type_id_5  building_rating_1  building_rating_2  \
# 0                     13                1.0                9.0
# 1                     19                NaN               10.0
# 2                     52                NaN               40.0
# 3                      2                NaN                2.0
# 4                     41                NaN               14.0
# ...                  ...                ...                ...
# 3701                   7                4.0                3.0
# 3702                  24                1.0               17.0
# 3703                  18                NaN               12.0
# 3704                  47                4.0               33.0
# 3705                   4                NaN                4.0
#
#       building_rating_3  building_rating_4  building_rating_5  renewal_Y  \
# 0                   3.0                NaN                NaN         13
# 1                   9.0                NaN                NaN         19
# 2                  12.0                NaN                NaN         52
# 3                   NaN                NaN                NaN          2
# 4                   2.0               25.0                NaN         41
# ...                 ...                ...                ...        ...
# 3701                NaN                NaN                NaN          7
# 3702                6.0                NaN                NaN         24
# 3703                6.0                NaN                NaN         18
# 3704               10.0                NaN                NaN         47
# 3705                NaN                NaN                NaN          4
#
#       vacant_days_propertytype_5  vacant_days_buildingrating_1  \
# 0                     365.714286                        914.00
# 1                     662.000000                           NaN
# 2                     373.411765                           NaN
# 3                     229.000000                           NaN
# 4                     524.483871                           NaN
# ...                          ...                           ...
# 3701                  300.285714                        365.75
# 3702                  298.086957                        549.00
# 3703                  281.166667                           NaN
# 3704                  749.323529                        730.25
# 3705                         NaN                           NaN
#
#       vacant_days_buildingrating_2  vacant_days_buildingrating_3  \
# 0                       297.000000                    229.000000
# 1                       502.750000                    821.250000
# 2                       416.000000                    209.142857
# 3                       229.000000                           NaN
# 4                       502.250000                    275.000000
# ...                            ...                           ...
# 3701                    213.000000                           NaN
# 3702                    311.823529                    201.200000
# 3703                    353.000000                    137.500000
# 3704                    771.148148                    578.333333
# 3705                           NaN                           NaN
#
#       vacant_days_buildingrating_4  vacant_days_buildingrating_5  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                       553.166667                           NaN
# ...                            ...                           ...
# 3701                           NaN                           NaN
# 3702                           NaN                           NaN
# 3703                           NaN                           NaN
# 3704                           NaN                           NaN
# 3705                           NaN                           NaN
#
#       occupied_days_propertytype_5  occupied_days_buildingrating_1  \
# 0                      3297.230769                         1238.00
# 1                      2561.052632                             NaN
# 2                      3641.288462                             NaN
# 3                      4848.500000                             NaN
# 4                      2287.195122                             NaN
# ...                            ...                             ...
# 3701                   3086.714286                         3598.00
# 3702                   2388.666667                         3408.00
# 3703                   2974.166667                             NaN
# 3704                   2580.510638                         3126.75
# 3705                   1376.250000                             NaN
#
#       occupied_days_buildingrating_2  occupied_days_buildingrating_3  \
# 0                        3278.666667                     4039.333333
# 1                        2547.300000                     2576.333333
# 2                        4041.750000                     2306.416667
# 3                        4848.500000                             NaN
# 4                        2870.714286                     1263.500000
# ...                              ...                             ...
# 3701                     2405.000000                             NaN
# 3702                     2762.470588                     1159.666667
# 3703                     3257.250000                     2408.000000
# 3704                     2488.121212                     2666.900000
# 3705                     1376.250000                             NaN
#
#       occupied_days_buildingrating_4  occupied_days_buildingrating_5  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                            2042.32                             NaN
# ...                              ...                             ...
# 3701                             NaN                             NaN
# 3702                             NaN                             NaN
# 3703                             NaN                             NaN
# 3704                             NaN                             NaN
# 3705                             NaN                             NaN
#
#       currently_occupied_fl_N  currently_occupied_fl_Y  \
# 0                         5.0                      8.0
# 1                         9.0                     10.0
# 2                        13.0                     39.0
# 3                         NaN                      2.0
# 4                        10.0                     31.0
# ...                       ...                      ...
# 3701                      1.0                      6.0
# 3702                      8.0                     16.0
# 3703                      2.0                     16.0
# 3704                     10.0                     37.0
# 3705                      3.0                      1.0
#
#       avg_rent_buildingrating_1  avg_rent_buildingrating_2  \
# 0                     12.425771                  12.624866
# 1                           NaN                  16.366925
# 2                           NaN                  11.751387
# 3                           NaN                  12.777495
# 4                           NaN                  10.670866
# ...                         ...                        ...
# 3701                  11.876562                  12.381419
# 3702                  17.465653                  16.742804
# 3703                        NaN                  16.435734
# 3704                  11.380579                  13.444017
# 3705                        NaN                  11.940065
#
#       avg_rent_buildingrating_3  avg_rent_buildingrating_4  \
# 0                     12.970470                        NaN
# 1                     17.534617                        NaN
# 2                     14.080592                        NaN
# 3                           NaN                        NaN
# 4                     12.764639                  13.225918
# ...                         ...                        ...
# 3701                        NaN                        NaN
# 3702                  27.180419                        NaN
# 3703                  20.225657                        NaN
# 3704                  15.771025                        NaN
# 3705                        NaN                        NaN
#
#       avg_rent_buildingrating_5  avg_estimated_rent
# 0                           NaN           12.689305
# 1                           NaN           16.920042
# 2                           NaN           12.285163
# 3                           NaN           12.777495
# 4                           NaN           12.260305
# ...                         ...                 ...
# 3701                        NaN           12.092929
# 3702                        NaN           19.382326
# 3703                        NaN           17.518569
# 3704                        NaN           13.770459
# 3705                        NaN           11.940065
#
# [3706 rows x 32 columns]

# %%
final.shape
# Out:
# (3706, 32)

# %%
final.columns
# Out:
# Index(['cbsaid', 'submarket_name', 'count_properties',
#        'construction_after_2000_N', 'construction_after_2000_Y',
#        'property_type_id_5', 'building_rating_1', 'building_rating_2',
#        'building_rating_3', 'building_rating_4', 'building_rating_5',
#        'renewal_Y', 'vacant_days_propertytype_5',
#        'vacant_days_buildingrating_1', 'vacant_days_buildingrating_2',
#        'vacant_days_buildingrating_3', 'vacant_days_buildingrating_4',
#        'vacant_days_buildingrating_5', 'occupied_days_propertytype_5',
#        'occupied_days_buildingrating_1', 'occupied_days_buildingrating_2',
#        'occupied_days_buildingrating_3', 'occupied_days_buildingrating_4',
#        'occupied_days_buildingrating_5', 'currently_occupied_fl_N',
#        'currently_occupied_fl_Y', 'avg_rent_buildingrating_1',
#        'avg_rent_buildingrating_2', 'avg_rent_buildingrating_3',
#        'avg_rent_buildingrating_4', 'avg_rent_buildingrating_5',
#        'avg_estimated_rent'],
#       dtype='object')

# %%
#final.to_csv('./Costar_tables/cluster_submarket.csv')

# %%
from sklearn.metrics.pairwise import cosine_similarity
#Fill na as 0 in all columns
final.fillna(0, inplace=True)
#join cbsaid with submarket column separated by /
final['cbsaid_submarket'] = final['cbsaid'].astype('str') + '/' + final['submarket_name']
#drop cbsaid, submarket and cbsaid_submarket and use the rest of the columns to check for similarity
final_sim = final.drop(columns=['cbsaid', 'submarket_name', 'cbsaid_submarket'])
final_sim
# Out:
#       count_properties  construction_after_2000_N  construction_after_2000_Y  \
# 0                   13                       11.0                        2.0
# 1                   19                       17.0                        2.0
# 2                   52                       45.0                        7.0
# 3                    2                        2.0                        0.0
# 4                   41                       41.0                        0.0
# ...                ...                        ...                        ...
# 3701                 7                        7.0                        0.0
# 3702                24                       13.0                       11.0
# 3703                18                       15.0                        3.0
# 3704                47                       41.0                        6.0
# 3705                 4                        4.0                        0.0
#
#       property_type_id_5  building_rating_1  building_rating_2  \
# 0                     13                1.0                9.0
# 1                     19                0.0               10.0
# 2                     52                0.0               40.0
# 3                      2                0.0                2.0
# 4                     41                0.0               14.0
# ...                  ...                ...                ...
# 3701                   7                4.0                3.0
# 3702                  24                1.0               17.0
# 3703                  18                0.0               12.0
# 3704                  47                4.0               33.0
# 3705                   4                0.0                4.0
#
#       building_rating_3  building_rating_4  building_rating_5  renewal_Y  \
# 0                   3.0                0.0                0.0         13
# 1                   9.0                0.0                0.0         19
# 2                  12.0                0.0                0.0         52
# 3                   0.0                0.0                0.0          2
# 4                   2.0               25.0                0.0         41
# ...                 ...                ...                ...        ...
# 3701                0.0                0.0                0.0          7
# 3702                6.0                0.0                0.0         24
# 3703                6.0                0.0                0.0         18
# 3704               10.0                0.0                0.0         47
# 3705                0.0                0.0                0.0          4
#
#       vacant_days_propertytype_5  vacant_days_buildingrating_1  \
# 0                     365.714286                        914.00
# 1                     662.000000                          0.00
# 2                     373.411765                          0.00
# 3                     229.000000                          0.00
# 4                     524.483871                          0.00
# ...                          ...                           ...
# 3701                  300.285714                        365.75
# 3702                  298.086957                        549.00
# 3703                  281.166667                          0.00
# 3704                  749.323529                        730.25
# 3705                    0.000000                          0.00
#
#       vacant_days_buildingrating_2  vacant_days_buildingrating_3  \
# 0                       297.000000                    229.000000
# 1                       502.750000                    821.250000
# 2                       416.000000                    209.142857
# 3                       229.000000                      0.000000
# 4                       502.250000                    275.000000
# ...                            ...                           ...
# 3701                    213.000000                      0.000000
# 3702                    311.823529                    201.200000
# 3703                    353.000000                    137.500000
# 3704                    771.148148                    578.333333
# 3705                      0.000000                      0.000000
#
#       vacant_days_buildingrating_4  vacant_days_buildingrating_5  \
# 0                         0.000000                           0.0
# 1                         0.000000                           0.0
# 2                         0.000000                           0.0
# 3                         0.000000                           0.0
# 4                       553.166667                           0.0
# ...                            ...                           ...
# 3701                      0.000000                           0.0
# 3702                      0.000000                           0.0
# 3703                      0.000000                           0.0
# 3704                      0.000000                           0.0
# 3705                      0.000000                           0.0
#
#       occupied_days_propertytype_5  occupied_days_buildingrating_1  \
# 0                      3297.230769                         1238.00
# 1                      2561.052632                            0.00
# 2                      3641.288462                            0.00
# 3                      4848.500000                            0.00
# 4                      2287.195122                            0.00
# ...                            ...                             ...
# 3701                   3086.714286                         3598.00
# 3702                   2388.666667                         3408.00
# 3703                   2974.166667                            0.00
# 3704                   2580.510638                         3126.75
# 3705                   1376.250000                            0.00
#
#       occupied_days_buildingrating_2  occupied_days_buildingrating_3  \
# 0                        3278.666667                     4039.333333
# 1                        2547.300000                     2576.333333
# 2                        4041.750000                     2306.416667
# 3                        4848.500000                        0.000000
# 4                        2870.714286                     1263.500000
# ...                              ...                             ...
# 3701                     2405.000000                        0.000000
# 3702                     2762.470588                     1159.666667
# 3703                     3257.250000                     2408.000000
# 3704                     2488.121212                     2666.900000
# 3705                     1376.250000                        0.000000
#
#       occupied_days_buildingrating_4  occupied_days_buildingrating_5  \
# 0                               0.00                             0.0
# 1                               0.00                             0.0
# 2                               0.00                             0.0
# 3                               0.00                             0.0
# 4                            2042.32                             0.0
# ...                              ...                             ...
# 3701                            0.00                             0.0
# 3702                            0.00                             0.0
# 3703                            0.00                             0.0
# 3704                            0.00                             0.0
# 3705                            0.00                             0.0
#
#       currently_occupied_fl_N  currently_occupied_fl_Y  \
# 0                         5.0                      8.0
# 1                         9.0                     10.0
# 2                        13.0                     39.0
# 3                         0.0                      2.0
# 4                        10.0                     31.0
# ...                       ...                      ...
# 3701                      1.0                      6.0
# 3702                      8.0                     16.0
# 3703                      2.0                     16.0
# 3704                     10.0                     37.0
# 3705                      3.0                      1.0
#
#       avg_rent_buildingrating_1  avg_rent_buildingrating_2  \
# 0                     12.425771                  12.624866
# 1                      0.000000                  16.366925
# 2                      0.000000                  11.751387
# 3                      0.000000                  12.777495
# 4                      0.000000                  10.670866
# ...                         ...                        ...
# 3701                  11.876562                  12.381419
# 3702                  17.465653                  16.742804
# 3703                   0.000000                  16.435734
# 3704                  11.380579                  13.444017
# 3705                   0.000000                  11.940065
#
#       avg_rent_buildingrating_3  avg_rent_buildingrating_4  \
# 0                     12.970470                   0.000000
# 1                     17.534617                   0.000000
# 2                     14.080592                   0.000000
# 3                      0.000000                   0.000000
# 4                     12.764639                  13.225918
# ...                         ...                        ...
# 3701                   0.000000                   0.000000
# 3702                  27.180419                   0.000000
# 3703                  20.225657                   0.000000
# 3704                  15.771025                   0.000000
# 3705                   0.000000                   0.000000
#
#       avg_rent_buildingrating_5  avg_estimated_rent
# 0                           0.0           12.689305
# 1                           0.0           16.920042
# 2                           0.0           12.285163
# 3                           0.0           12.777495
# 4                           0.0           12.260305
# ...                         ...                 ...
# 3701                        0.0           12.092929
# 3702                        0.0           19.382326
# 3703                        0.0           17.518569
# 3704                        0.0           13.770459
# 3705                        0.0           11.940065
#
# [3706 rows x 30 columns]

# %%
#getting the similarity matrix
similarity = cosine_similarity(final_sim)
similarity
# Out:
# array([[1.        , 0.95054486, 0.92192015, ..., 0.94707433, 0.90830603,
#         0.72993041],
#        [0.95054486, 1.        , 0.96115579, ..., 0.97566632, 0.81894584,
#         0.78728529],
#        [0.92192015, 0.96115579, 1.        , ..., 0.99503123, 0.78659792,
#         0.91465718],
#        ...,
#        [0.94707433, 0.97566632, 0.99503123, ..., 1.        , 0.80021624,
#         0.87296546],
#        [0.90830603, 0.81894584, 0.78659792, ..., 0.80021624, 1.        ,
#         0.63590726],
#        [0.72993041, 0.78728529, 0.91465718, ..., 0.87296546, 0.63590726,
#         1.        ]])

# %%
sim=final[['cbsaid_submarket', 'cbsaid', 'count_properties']].pivot(index='cbsaid', columns="cbsaid_submarket").\
    reset_index(drop=True).rename(index={'cbsaid_submarket': ' '})
sim
sim.columns = sim.columns.get_level_values(1)
sim_df = pd.DataFrame(similarity, columns=sim.columns).rename(index={'cbsaid_submarket': ''})
sim_df
sim_df['cbsaid_submarket'] = sim.columns
cols = list(sim_df.columns)
cols = cols[::-1]
sim_df = sim_df[cols]
sim_df
# Out:
# cbsaid_submarket              cbsaid_submarket  49820.0/Zapata  \
# 0                             10100.0/Aberdeen        0.729930
# 1                             10140.0/Aberdeen        0.787285
# 2                              10180.0/Abilene        0.914657
# 3                 10180.0/Chimney Rock Area MF        0.998859
# 4                  10180.0/Downtown Abilene MF        0.812416
# ...                                        ...             ...
# 3701                       49700.0/Yuba County        0.727050
# 3702                  49740.0/Downtown Yuma MF        0.703269
# 3703                              49740.0/Yuma        0.872965
# 3704                        49780.0/Zanesville        0.635907
# 3705                            49820.0/Zapata        1.000000
#
# 1                                  0.769964       0.712947
# 2                                  0.750251       0.696787
# 3                                  0.638019       0.580956
# 4                                  0.817998       0.807896
# ...                                     ...            ...
# 3701                               0.817352       0.685693
# 3702                               0.895440       0.764592
# 3703                               0.752893       0.699424
# 3704                               0.926389       0.809369
# 3705                               0.628421       0.576076
#
# cbsaid_submarket  10300.0/Lenawee County  10300.0/Adrian  10220.0/Ada  \
# 0                               0.945908        0.729933     0.737496
# 1                               0.996806        0.787268     0.695498
# 2                               0.978153        0.914660     0.798959
# 3                               0.837098        0.998874     0.866412
# 4                               0.853946        0.812408     0.717649
# ...                                  ...             ...          ...
# 3701                            0.613477        0.727049     0.967680
# 3702                            0.717861        0.703250     0.944939
# 3703                            0.986173        0.872954     0.762365
# 3704                            0.814786        0.635895     0.844820
# 3705                            0.831034        0.999962     0.863134
#
# cbsaid_submarket  10180.0/Westwood Richland MF  \
# 0                                     0.906076
# 1                                     0.973005
# 2                                     0.965147
# 3                                     0.846833
# 4                                     0.857956
# ...                                        ...
# 3701                                  0.609338
# 3702                                  0.716761
# 3703                                  0.963870
# 3704                                  0.788976
# 3705                                  0.839938
#
# cbsaid_submarket  10180.0/River Oaks-Brookhollow MF  10180.0/North Abilene MF  \
# 0                                          0.940641                  0.729927
# 1                                          0.994480                  0.787250
# 2                                          0.978299                  0.914598
# 3                                          0.840347                  0.998886
# 4                                          0.857949                  0.812348
# ...                                             ...                       ...
# 3701                                       0.612137                  0.727052
# 3702                                       0.719887                  0.703229
# 3703                                       0.984670                  0.872943
# 3704                                       0.811205                  0.635837
# 3705                                       0.834001                  0.999969
#
# cbsaid_submarket  10180.0/Downtown Abilene MF  10180.0/Chimney Rock Area MF  \
# 0                                    0.785421                      0.732587
# 1                                    0.837599                      0.794846
# 2                                    0.874335                      0.918020
# 3                                    0.819080                      1.000000
# 4                                    1.000000                      0.819080
# ...                                       ...                           ...
# 3701                                 0.593409                      0.729450
# 3702                                 0.654999                      0.706379
# 3703                                 0.863192                      0.876166
# 3704                                 0.686082                      0.644135
# 3705                                 0.812416                      0.998859
#
# cbsaid_submarket  10180.0/Abilene  10140.0/Aberdeen  10100.0/Aberdeen
# 0                        0.921920          0.950545          1.000000
# 1                        0.961156          1.000000          0.950545
# 2                        1.000000          0.961156          0.921920
# 3                        0.918020          0.794846          0.732587
# 4                        0.874335          0.837599          0.785421
# ...                           ...               ...               ...
# 3701                     0.667037          0.585072          0.676724
# 3702                     0.741937          0.701187          0.805808
# 3703                     0.995031          0.975666          0.947074
# 3704                     0.786598          0.818946          0.908306
# 3705                     0.914657          0.787285          0.729930
#
# [3706 rows x 3707 columns]

# %%
#check how many are similar and > 99% similarity
test = sim_df[sim_df['10620.0/Albemarle'] > 0.99][['cbsaid_submarket', '10620.0/Albemarle']].\
    sort_values(by = '10620.0/Albemarle', ascending=False)
#only taking top 5
test[1:6]
# Out:
# cbsaid_submarket       cbsaid_submarket  10620.0/Albemarle
# 1028                      19940.0/Dixon           0.999996
# 3267                44900.0/Summerville           0.999995
# 3705                     49820.0/Zapata           0.999993
# 2063              33500.0/North Hill MF           0.999991
# 1223                   23300.0/Freeport           0.999990

# %%
final[(final['cbsaid'] == 10620.0) | (final['cbsaid']==19940.0)]
# Out:
#        cbsaid            submarket_name  count_properties  \
# 32    10620.0                 Albemarle                 2
# 33    10620.0             Stanly County                18
# 1028  19940.0                     Dixon                 1
# 1029  19940.0  I-39 Corridor/Lee County                 4
#
#       construction_after_2000_N  construction_after_2000_Y  \
# 32                          2.0                        0.0
# 33                         15.0                        3.0
# 1028                        1.0                        0.0
# 1029                        4.0                        0.0
#
#       property_type_id_5  building_rating_1  building_rating_2  \
# 32                     2                0.0                2.0
# 33                    18                2.0               13.0
# 1028                   1                0.0                1.0
# 1029                   4                0.0                4.0
#
#       building_rating_3  building_rating_4  building_rating_5  renewal_Y  \
# 32                  0.0                0.0                0.0          2
# 33                  3.0                0.0                0.0         18
# 1028                0.0                0.0                0.0          1
# 1029                0.0                0.0                0.0          4
#
#       vacant_days_propertytype_5  vacant_days_buildingrating_1  \
# 32                      0.000000                           0.0
# 33                    348.909091                         457.0
# 1028                    0.000000                           0.0
# 1029                  251.250000                           0.0
#
#       vacant_days_buildingrating_2  vacant_days_buildingrating_3  \
# 32                           0.000                           0.0
# 33                         274.125                         731.0
# 1028                         0.000                           0.0
# 1029                       251.250                           0.0
#
#       vacant_days_buildingrating_4  vacant_days_buildingrating_5  \
# 32                             0.0                           0.0
# 33                             0.0                           0.0
# 1028                           0.0                           0.0
# 1029                           0.0                           0.0
#
#       occupied_days_propertytype_5  occupied_days_buildingrating_1  \
# 32                     1123.500000                             0.0
# 33                     2426.611111                          2430.0
# 1028                   1500.000000                             0.0
# 1029                   2218.000000                             0.0
#
#       occupied_days_buildingrating_2  occupied_days_buildingrating_3  \
# 32                       1123.500000                             0.0
# 33                       2372.923077                          2657.0
# 1028                     1500.000000                             0.0
# 1029                     2218.000000                             0.0
#
#       occupied_days_buildingrating_4  occupied_days_buildingrating_5  \
# 32                               0.0                             0.0
# 33                               0.0                             0.0
# 1028                             0.0                             0.0
# 1029                             0.0                             0.0
#
#       currently_occupied_fl_N  currently_occupied_fl_Y  \
# 32                        1.0                      1.0
# 33                        8.0                     10.0
# 1028                      0.0                      1.0
# 1029                      0.0                      4.0
#
#       avg_rent_buildingrating_1  avg_rent_buildingrating_2  \
# 32                     0.000000                  13.324729
# 33                     9.332098                  12.527641
# 1028                   0.000000                  14.373124
# 1029                   0.000000                  14.590028
#
#       avg_rent_buildingrating_3  avg_rent_buildingrating_4  \
# 32                     0.000000                        0.0
# 33                    14.749485                        0.0
# 1028                   0.000000                        0.0
# 1029                   0.000000                        0.0
#
#       avg_rent_buildingrating_5  avg_estimated_rent  \
# 32                          0.0           13.324729
# 33                          0.0           12.542888
# 1028                        0.0           14.373124
# 1029                        0.0           14.590028
#
#                       cbsaid_submarket
# 32                   10620.0/Albemarle
# 33               10620.0/Stanly County
# 1028                     19940.0/Dixon
# 1029  19940.0/I-39 Corridor/Lee County
